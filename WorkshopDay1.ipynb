# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/grive')
# Out:
# Mounted at /content/grive

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Yorko/mlcourse.ai/master/data/telecom_churn.csv")

# %%
df.head()
# Out:
#   State  Account length  ...  Customer service calls  Churn
# 0    KS             128  ...                       1  False
# 1    OH             107  ...                       1  False
# 2    NJ             137  ...                       0  False
# 3    OH              84  ...                       2  False
# 4    OK              75  ...                       3  False
#
# [5 rows x 20 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of      State  Account length  ...  Customer service calls  Churn
# 0       KS             128  ...                       1  False
# 1       OH             107  ...                       1  False
# 2       NJ             137  ...                       0  False
# 3       OH              84  ...                       2  False
# 4       OK              75  ...                       3  False
# ...    ...             ...  ...                     ...    ...
# 3328    AZ             192  ...                       2  False
# 3329    WV              68  ...                       3  False
# 3330    RI              28  ...                       2  False
# 3331    CT             184  ...                       2  False
# 3332    TN              74  ...                       0  False
#
# [3333 rows x 20 columns]>

# %%
df.shape
# Out:
# (3333, 20)

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Account length    Area code  ...  Total intl charge  Customer service calls
# count     3333.000000  3333.000000  ...        3333.000000             3333.000000
# mean       101.064806   437.182418  ...           2.764581                1.562856
# std         39.822106    42.371290  ...           0.753773                1.315491
# min          1.000000   408.000000  ...           0.000000                0.000000
# 25%         74.000000   408.000000  ...           2.300000                1.000000
# 50%        101.000000   415.000000  ...           2.780000                1.000000
# 75%        127.000000   510.000000  ...           3.270000                2.000000
# max        243.000000   510.000000  ...           5.400000                9.000000
#
# [8 rows x 16 columns]

# %%
df[["Total day minutes"]]
# Out:
#       Total day minutes
# 0                 265.1
# 1                 161.6
# 2                 243.4
# 3                 299.4
# 4                 166.7
# ...                 ...
# 3328              156.2
# 3329              231.1
# 3330              180.8
# 3331              213.8
# 3332              234.4
#
# [3333 rows x 1 columns]

# %%
df.iloc[1]
# Out:
# State                        OH
# Account length              107
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        26
# Total day minutes         161.6
# Total day calls             123
# Total day charge          27.47
# Total eve minutes         195.5
# Total eve calls             103
# Total eve charge          16.62
# Total night minutes       254.4
# Total night calls           103
# Total night charge        11.45
# Total intl minutes         13.7
# Total intl calls              3
# Total intl charge           3.7
# Customer service calls        1
# Churn                     False
# Name: 1, dtype: object

# %%
df.iloc[2]
# Out:
# State                        NJ
# Account length              137
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         243.4
# Total day calls             114
# Total day charge          41.38
# Total eve minutes         121.2
# Total eve calls             110
# Total eve charge           10.3
# Total night minutes       162.6
# Total night calls           104
# Total night charge         7.32
# Total intl minutes         12.2
# Total intl calls              5
# Total intl charge          3.29
# Customer service calls        0
# Churn                     False
# Name: 2, dtype: object

# %%
df["Total day minutes"].iloc[1]
# Out:
# 161.6

# %%
df["Total day minutes"].head()
# Out:
# 0    265.1
# 1    161.6
# 2    243.4
# 3    299.4
# 4    166.7
# Name: Total day minutes, dtype: float64

# %%
df["Churn"].value_counts()
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
df["International plan"].value_counts()
# Out:
# No     3010
# Yes     323
# Name: International plan, dtype: int64

# %%
df.head()
# Out:
#   State  Account length  ...  Customer service calls  Churn
# 0    KS             128  ...                       1  False
# 1    OH             107  ...                       1  False
# 2    NJ             137  ...                       0  False
# 3    OH              84  ...                       2  False
# 4    OK              75  ...                       3  False
#
# [5 rows x 20 columns]

# %%
df.sort_values(by="Total day charge").head()
# Out:
#      State  Account length  ...  Customer service calls  Churn
# 1345    SD              98  ...                       4   True
# 1397    VT             101  ...                       1  False
# 2736    OK             127  ...                       3  False
# 2753    OH             134  ...                       2  False
# 1986    WI              70  ...                       0  False
#
# [5 rows x 20 columns]

# %%
df["Total day charge"].mean()
# Out:
# 30.562307230723093

# %%
df.head()
# Out:
#   State  Account length  ...  Customer service calls  Churn
# 0    KS             128  ...                       1  False
# 1    OH             107  ...                       1  False
# 2    NJ             137  ...                       0  False
# 3    OH              84  ...                       2  False
# 4    OK              75  ...                       3  False
#
# [5 rows x 20 columns]

# %%
df[df['Total intl calls'] > 3]
# Out:
#      State  Account length  ...  Customer service calls  Churn
# 2       NJ             137  ...                       0  False
# 3       OH              84  ...                       2  False
# 5       AL             118  ...                       0  False
# 6       MA             121  ...                       3  False
# 7       MO             147  ...                       0  False
# ...    ...             ...  ...                     ...    ...
# 3328    AZ             192  ...                       2  False
# 3329    WV              68  ...                       3  False
# 3330    RI              28  ...                       2  False
# 3331    CT             184  ...                       2  False
# 3332    TN              74  ...                       0  False
#
# [1998 rows x 20 columns]

# %%
df[df["State"]=='OH']
# Out:
#      State  Account length  ...  Customer service calls  Churn
# 1       OH             107  ...                       1  False
# 3       OH              84  ...                       2  False
# 152     OH              65  ...                       1  False
# 156     OH              83  ...                       0   True
# 231     OH              63  ...                       1  False
# ...    ...             ...  ...                     ...    ...
# 3249    OH             160  ...                       0  False
# 3251    OH              88  ...                       2  False
# 3286    OH             106  ...                       0  False
# 3325    OH              78  ...                       2  False
# 3326    OH              96  ...                       1  False
#
# [78 rows x 20 columns]

# %%
df[df["Number vmail messages"]>20]
# Out:
#      State  Account length  ...  Customer service calls  Churn
# 0       KS             128  ...                       1  False
# 1       OH             107  ...                       1  False
# 6       MA             121  ...                       3  False
# 9       WV             141  ...                       0  False
# 16      ID              85  ...                       1  False
# ...    ...             ...  ...                     ...    ...
# 3305    IN              58  ...                       2  False
# 3306    AL             106  ...                       1  False
# 3316    MS             103  ...                       0  False
# 3328    AZ             192  ...                       2  False
# 3332    TN              74  ...                       0  False
#
# [813 rows x 20 columns]

# %%
df[df["State"]=='OH'].value_counts()
# Out:
# State  Account length  Area code  International plan  Voice mail plan  Number vmail messages  Total day minutes  Total day calls  Total day charge  Total eve minutes  Total eve calls  Total eve charge  Total night minutes  Total night calls  Total night charge  Total intl minutes  Total intl calls  Total intl charge  Customer service calls  Churn
# OH     169             408        No                  No               0                      147.2              115              25.02             161.9              123              13.76             142.1                103                6.39                7.2                 6                 1.94               3                       False    1
# ...

# %%
df["International plan"].value_counts()
# Out:
# No     3010
# Yes     323
# Name: International plan, dtype: int64

# %%
df["State"].value_counts()
# Out:
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# OH     78
# OR     78
# WY     77
# VA     77
# CT     74
# VT     73
# ID     73
# MI     73
# UT     72
# TX     72
# IN     71
# KS     70
# MD     70
# NC     68
# MT     68
# NJ     68
# CO     66
# NV     66
# WA     66
# MS     65
# RI     65
# MA     65
# AZ     64
# MO     63
# FL     63
# NM     62
# ND     62
# ME     62
# NE     61
# DE     61
# OK     61
# SC     60
# SD     60
# KY     59
# IL     58
# NH     56
# AR     55
# GA     54
# DC     54
# HI     53
# TN     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: State, dtype: int64

# %%
df.head()
# Out:
#   State  Account length  ...  Customer service calls  Churn
# 0    KS             128  ...                       1  False
# 1    OH             107  ...                       1  False
# 2    NJ             137  ...                       0  False
# 3    OH              84  ...                       2  False
# 4    OK              75  ...                       3  False
#
# [5 rows x 20 columns]

# %%
df["Churn"]=df["Churn"].astype("int64")

# %%
df["Churn"].unique()
# Out:
# array([0, 1])

# %%
df.head()
# Out:
#   State  Account length  ...  Customer service calls Churn
# 0    KS             128  ...                       1     0
# 1    OH             107  ...                       1     0
# 2    NJ             137  ...                       0     0
# 3    OH              84  ...                       2     0
# 4    OK              75  ...                       3     0
#
# [5 rows x 20 columns]

# %%
sns.countplot("Churn",data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot("Churn",data=df,hue="Churn")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(x = "Number vmail messages",y = "Total day calls",data = df)
